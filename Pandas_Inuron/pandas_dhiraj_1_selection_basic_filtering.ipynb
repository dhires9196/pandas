# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import requests

# %%
requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
# <Response [200]>

# %%
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
res.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/44705',
#   'id': 1068598638,
#   'node_id': 'I_kwDOAA0YD84_sYVu',
#   'number': 44705,
#   'title': "BUG: Python's date and time objects do not roundtrip with JSON orient='table'",
#   'user': {'login': 'jmg-duarte',
#    'id': 15343819,
#    'node_id': 'MDQ6VXNlcjE1MzQzODE5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15343819?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jmg-duarte',
#    'html_url': 'https://github.com/jmg-duarte',
# ...

# %%
js=res.json()

# %%
js[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/44705/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/44705',
#  'id': 1068598638,
#  'node_id': 'I_kwDOAA0YD84_sYVu',
#  'number': 44705,
#  'title': "BUG: Python's date and time objects do not roundtrip with JSON orient='table'",
#  'user': {'login': 'jmg-duarte',
#   'id': 15343819,
#   'node_id': 'MDQ6VXNlcjE1MzQzODE5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/15343819?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/jmg-duarte',
#   'html_url': 'https://github.com/jmg-duarte',
# ...

# %%
js[0]['title']
# Out:
# "BUG: Python's date and time objects do not roundtrip with JSON orient='table'"

# %%
for i in range(len(js)):
    print(js[i]['title'])
# Out:
# BUG: Python's date and time objects do not roundtrip with JSON orient='table'
# BUG: Can't use iloc to set a subset of a dataframe to a two-dimensional categorical data array.
# DOC: fix examples in Timestamp functions
# TST: Use IPython instance fixture to avoid file leak
# TST: de-duplicate fixtures
# BUG: Series.where with incompatible NA value
# BUG: Apply ewm to GroupBy object results in duplicate index columns
# TST: read_csv raisin error with string dtype and parse dates
# BUG: dtypes cast when reading JSON
# API: value_counts consistently return int64 dtype
# REF: simplify Block.where (and subtle alignment bug)
# ENH: Add a `reset` parameter to `cumsum`
# ENH: pandas.DataFrame.attrs
# ENH: Add indexing syntax to GroupBy.nth()
# BUG:
# TST: fix Nullable xfails
# BUG: the precision of big integer in read_json
# CI: Try to not auto-cancel on master
# REF: hold PeriodArray in NDArrayBackedExtensionBlock
# 44414 data frame attributes not propagating with astype
# ...

# %%
js[0]['user']['node_id']
# Out:
# 'MDQ6VXNlcjE1MzQzODE5'

# %%
for i in range(len(js)):
    print(js[i]['user']['node_id'])
# Out:
# MDQ6VXNlcjE1MzQzODE5
# MDQ6VXNlcjEwNzEyMTA5
# MDQ6VXNlcjIzNDUzNjkx
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjEzNDczNjg4
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjg1MTgyODg=
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjY0NTI2NzU=
# U_kgDOBa321Q
# MDQ6VXNlcjg5MjcyNTg=
# MDQ6VXNlcjgwMTkwOTA5
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjU0Mjc0MjE5
# MDQ6VXNlcjQ3OTYzMjE1
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjQ3MDg2NTYx
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwMjA0OTY=
# MDQ6VXNlcjc1OTc1MjY4
# MDQ6VXNlcjkxMjQ4Mjc=
# MDQ6VXNlcjY4MDUzMzk2
# MDQ6VXNlcjgyMzg4MDQ=
# MDQ6VXNlcjEwMjA0OTY=
# MDQ6VXNlcjQ0MDgwMzkw

# %%
df4=pd.DataFrame(js)

# %%
df4.to_csv('jason_dump.csv')

# %%
js[0]['user']
# Out:
# {'login': 'jmg-duarte',
#  'id': 15343819,
#  'node_id': 'MDQ6VXNlcjE1MzQzODE5',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/15343819?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jmg-duarte',
#  'html_url': 'https://github.com/jmg-duarte',
#  'followers_url': 'https://api.github.com/users/jmg-duarte/followers',
#  'following_url': 'https://api.github.com/users/jmg-duarte/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jmg-duarte/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jmg-duarte/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jmg-duarte/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jmg-duarte/orgs',
#  'repos_url': 'https://api.github.com/users/jmg-duarte/repos',
#  'events_url': 'https://api.github.com/users/jmg-duarte/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jmg-duarte/received_events',
#  'type': 'User',
# ...

# %%
l=[]
for i in range(len(js)):
    l.append(js[i]['user'])
pd.DataFrame(l)
# Out:
#                        login        id               node_id  \
# 0                 jmg-duarte  15343819  MDQ6VXNlcjE1MzQzODE5
# 1                mvashishtha  10712109  MDQ6VXNlcjEwNzEyMTA5
# 2                valentinoli  23453691  MDQ6VXNlcjIzNDUzNjkx
# 3                  mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4               jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5               jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 6              matteosantama  13473688  MDQ6VXNlcjEzNDczNjg4
# 7                      phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 8   ConstantinoSchillebeeckx   8518288  MDQ6VXNlcjg1MTgyODg=
# 9               jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 10              jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 11               JivanRoquet   6452675  MDQ6VXNlcjY0NTI2NzU=
# 12                 shrutir21  95286997          U_kgDOBa321Q
# 13              johnzangwill   8927258  MDQ6VXNlcjg5MjcyNTg=
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df1=df[df.dtypes[df.dtypes=='object'].index]

# %%
df1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1.describe()
# Out:
#                     Name   Sex Ticket Cabin Embarked
# count                891   891    891   204      889
# unique               891     2    681   147        3
# top     Mineff, Mr. Ivan  male   1601    G6        S
# freq                   1   577      7     4      644

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[df.dtypes[df.dtypes=='float'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][5:10:3]
# Out:
# 5                                     Moran, Mr. James
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# Name: Name, dtype: object

# %%
df['Ticket'][5:16]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# 15       248706
# Name: Ticket, dtype: object

# %%
df['Ticket'].sort_values
# Out:
# <bound method Series.sort_values of 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object>

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
for i in df.columns:
    print(df[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['sudh']='kumar'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['sudh1']=df['PassengerId']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pddf['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
ser=df['Cabin'][df['Cabin'].isnull()==False]

# %%
ser.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[[1,3,7,8]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch    Ticket     Fare Cabin Embarked   sudh  sudh1
# 1      0  PC 17599  71.2833   C85        C  kumar      2
# 3      0    113803  53.1000  C123        S  kumar      4
# 7      1    349909  21.0750   NaN        S  kumar      8
# 8      2    347742  11.1333   NaN        S  kumar      9

# %%
#person name who has paid the highest fare
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare'][df['Fare']==max(df['Fare'])].index
# Out:
# Int64Index([258, 679, 737], dtype='int64')

# %%
df.iloc[df['Fare'][df['Fare']==max(df['Fare'])].index]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

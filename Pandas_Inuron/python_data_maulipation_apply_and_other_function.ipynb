# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(20)
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('2021-07-08',periods=10),columns=['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new']=df['c']+df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913

# %%
df['new_col_squre_d']=df['d'].apply(lambda x:x**2)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693

# %%
s= lambda x:x**2

# %%
s(2)
# Out:
# 4

# %%
df['new_col_squre_d_log']=df['d'].apply(lambda x:np.log(x))

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
#
#             new_col_squre_d_log
# 2021-07-08                  NaN
# 2021-07-09                  NaN
# ...

# %%
def test(x):
    if (x <0):
        return x
    else:
        return np.log(x)

# %%
df['new_col_squre_d_log_1']=df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
#
#             new_col_squre_d_log  new_col_squre_d_log_1
# 2021-07-08                  NaN              -2.343262
# ...

# %%
def test1(x):
    if x <0:
        return 1
    else:
        return 0

# %%
df['new_a']=df['a'].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
#
#             new_col_squre_d_log  new_col_squre_d_log_1  new_a
# ...

# %%
df.sort_values(by='b')
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
#
#             new_col_squre_d_log  new_col_squre_d_log_1  new_a
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2021-07-08', '2021-07-09', '2021-07-10', '2021-07-11',
#                '2021-07-12', '2021-07-13', '2021-07-14', '2021-07-15',
#                '2021-07-16', '2021-07-17'],
#               dtype='datetime64[ns]', freq='D')

# %%
df['new_date']=df.index

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
#
#             new_col_squre_d_log  new_col_squre_d_log_1  new_a   new_date
# ...

# %%
df.dtypes
# Out:
# a                               float64
# b                               float64
# c                               float64
# d                               float64
# new                             float64
# new_col_squre_d                 float64
# new_col_squre_d_log             float64
# new_col_squre_d_log_1           float64
# new_a                             int64
# new_date                 datetime64[ns]
# dtype: object

# %%
df['day']=df.index.day
df['month']=df.index.month
df['year']=df.index.year

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
#
#             new_col_squre_d_log  new_col_squre_d_log_1  new_a   new_date  day  \
# ...

# %%
df['new_col']=df.index.day_name()

# %%
df
# Out:
#                    a         b         c         d       new  new_col_squre_d  \
# 2021-07-08  0.883893  0.195865  0.357537 -2.343262 -1.985725         5.490876
# 2021-07-09 -1.084833  0.559696  0.939469 -0.978481 -0.039012         0.957425
# 2021-07-10  0.503097  0.406414  0.323461 -0.493411 -0.169950         0.243454
# 2021-07-11 -0.792017 -0.842368 -1.279503  0.245715 -1.033787         0.060376
# 2021-07-12 -0.044195  1.567633  1.051109  0.406368  1.457477         0.165135
# 2021-07-13 -0.168646 -3.189703  1.120132  1.332778  2.452910         1.776298
# 2021-07-14 -0.243339 -0.130031 -0.109017  1.556186  1.447169         2.421716
# 2021-07-15  0.128778 -2.066949 -0.885493 -1.104579 -1.990073         1.220096
# 2021-07-16  0.932866  2.059838 -0.934938 -1.612990 -2.547928         2.601737
# 2021-07-17  0.527070 -1.551101  0.329613 -1.136527 -0.806913         1.291693
#
#             new_col_squre_d_log  new_col_squre_d_log_1  new_a   new_date  day  \
# ...

# %%
df.groupby(by='new_col').count()
# Out:
#            a  b  c  d  new  new_col_squre_d  new_col_squre_d_log  \
# new_col
# Friday     2  2  2  2    2                2                    0
# Monday     1  1  1  1    1                1                    1
# Saturday   2  2  2  2    2                2                    0
# Sunday     1  1  1  1    1                1                    1
# Thursday   2  2  2  2    2                2                    0
# Tuesday    1  1  1  1    1                1                    1
# Wednesday  1  1  1  1    1                1                    1
#
#            new_col_squre_d_log_1  new_a  new_date  day  month  year
# new_col
# Friday                         2      2         2    2      2     2
# Monday                         1      1         1    1      1     1
# Saturday                       2      2         2    2      2     2
# Sunday                         1      1         1    1      1     1
# Thursday                       2      2         2    2      2     2
# ...
